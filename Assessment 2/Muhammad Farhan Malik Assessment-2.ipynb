# %% [markdown]
# ### Task 1: Printing a Message

# %%
print("Hello, everyone! I am learning Python. 😄")
# Out:
# Hello, everyone! I am learning Python. 😄

# %% [markdown]
# ### Task 2: Declaring Variables

# %%
name = "Muhammad Farhan Malik"
age = 12
fa = "Spider"

print("Name:", name) 
print("age:", age)
print("Favrite name:", fa)
# Out:
# Name: Muhammad Farhan Malik
# age: 12
# Favrite name: Spider

# %% [markdown]
# ### Task 3: Combining Variables in a Message

# %%
print(f'''My name is {name}, i am {age} years old, and i love {fa}!''')
# Out:
# My name is Muhammad Farhan Malik, i am 12 years old, and i love Spider!

# %% [markdown]
# ### Task 4: Playing with Different Data Types

# %%
fm = "Spider Man"
by = 1996
fs = 2.8
print("\nFavorite Movie: ", fm)
print("Birth year: ", by)
print("Price of Snack: ", fs)
# Out:
# Favorite Movie:  Spider Man
# Birth year:  1996
# Price of Snack:  2.8

# %% [markdown]
# ### Task 5: Your Favorite Hobby

# %%
hobby = "reading book"

print("\nMy favorite hobby is [your hobby].")
print(f'''My favorite hobby is {hobby}.''')
# Out:
# My favorite hobby is [your hobby].
# My favorite hobby is reading book.
