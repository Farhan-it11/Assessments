# %% [raw]
# # 1. Write a Python program that can do the following:
# # - You have $50
# # - You buy an item that is $15, that has a 3% tax
# # - Print how much money you have left, after purchasing the item.

# %%
blance = 50
print('My blance is', blance,'.')
buy_item = 15
tax = (3 * 1/100) * 15
total_price = buy_item + tax
print("Item's price with tax is", total_price,'.')
print ('Remaining balance after purchasing: ', blance - total_price,'.')
# Out:
# My blance is 50 .
# Item's price with tax is 15.45 .
# Remaining balance after purchasing:  34.55 .

# %% [raw]
# # 2. Ask the user how many days until their birthday
# # - Print an approx. number of weeks until their birthday
# # - 1 week is = to 7 days.

# %%
days = int(input("Your birthday coming in how many day: "))
weeks = days / 7
print(f'Your birthday is after {weeks} weeks.')
# Out:
# Your birthday coming in how many day:  56
# Your birthday is after 8.0 weeks.

# %% [raw]
# # 3. Create a variable “Grade” holding an integer between 0 to100. Code to print
# # the letter Grade of the number Grade variable.
# # Grades:
# # - A = 90 - 100
# # - B = 80 - 89
# # - C = 70-79
# # - D = 60 - 69
# # - F = 0 – 59

# %%
Grade = 56
if Grade <=100 and Grade >=90:
        print('- A = 90 - 100')
elif Grade <=89 and Grade >=80:
        print('- B = 80 - 89')
elif Grade <=79 and Grade >=70:
        print('- C = 70 - 79')
elif Grade <=69 and Grade >=60:
        print('- A = 60 - 69')
else:
        print('- A = 0 - 59')
# Out:
# - A = 0 - 59
